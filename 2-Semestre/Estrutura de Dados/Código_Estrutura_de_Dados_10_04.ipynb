# %%
# Declara uma lista para armazenar os produtos
produtos = []

# Pede ao usuário para adicionar um produto
while True:
    print("Por favor, informe seu CPF: ")
    cpf = input()

    # Pede ao usuário para informar o nome do produto
    print("Por favor, informe o nome do produto: ")
    nome = input()

    # Pede ao usuário para informar a descrição do produto
    print("Por favor, informe a descrição do produto: ")
    descricao = input()

    # Pede ao usuário para informar a quantidade do produto
    print("Por favor, informe a quantidade do produto: ")
    quantidade = int(input())

    # Pede ao usuário para informar o valor total do produto
    print("Por favor, informe o valor total do produto: ")
    valor_total = float(input())

    # Pede ao usuário para informar a marca do produto
    print("Por favor, informe a marca do produto: ")
    marca = input()

    # Calcula o valor final do produto
    faturamento = (quantidade / valor_total) + 0.2 * valor_total
    valor_final = faturamento

    # Define a seção do produto
    if "Brinco" in nome or "Colar" in nome or "Anel" in nome or "Pulseira" in nome or "Gargantilha" in nome or "Tornozeleira" in nome or "Bracelete" in nome:
        secao = 1
    elif "Batom" in nome or "Base" in nome or "Pó" in nome or "Rímel" in nome or "Blush" in nome or "Iluminador" in nome or "Gloss" in nome or "Demaquilante" in nome or "Pincel" in nome:
        secao = 2
    elif "Laço" in nome or "Presilha" in nome or "Arquinho" in nome or "Pente" in nome or "Escova" in nome or "Creme" in nome or "Shampoo" in nome or "Condicionador" in nome:
        secao = 3
    elif "Esmalte" in nome or "Acetona" in nome or "Palito" in nome or "Adesivo" in nome or "Algodão" in nome or "Lixa" in nome or "Cortador" in nome:
        secao = 4
    elif "Chaveiro" in nome or "Elástico" in nome or "Jóia" in nome or "Necessaire" in nome or "Bolsa" in nome:
        secao = 5
    else:
        secao = None

    # Cria um dicionário para armazenar as informações do produto
    produto = {
        "cpf": cpf,
        "nome": nome,
        "quantidade": quantidade,
        "valor_total": valor_total,
        "marca": marca,
        "valor_final": valor_final,
        "secao": secao
    }

    # Adiciona o produto à lista de produtos
    produtos.append(produto)

    # Pede ao usuário se deseja adicionar outro produto
    print("Deseja adicionar outro produto? (s/n)")
    resposta = input()

    if resposta != "s":
        break

# Imprime a lista de produtos
for produto in produtos:
    print(produto)
# Out:
# Por favor, informe seu CPF:
