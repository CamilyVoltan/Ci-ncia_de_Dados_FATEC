# %%
import pandas as pd

df = pd.read_excel('pedaço.xlsx')

df
# Out:
#                    Cidade Estado Avaliada  \
# 0                  Cidade     AM      NÃO
# 1                  Acaraú     CE      NÃO
# 2                   Arame     MA      NÃO
# 3                  Agudos     SP      NÃO
# 4                 Anguera     BA      NÃO
# 5                   Ceres     GO      NÃO
# 6                   Irupi     ES      NÃO
# 7              Alcântaras     CE      NÃO
# 8         Abadia de Goiás     GO      NÃO
# 9     Abadia dos Dourados     MG      NÃO
# 10              Abadiânia     GO      NÃO
# 11                 Abaeté     MG      NÃO
# 12             Abaetetuba     PA      NÃO
# 13                Abaiara     CE      NÃO
# 14                 Abaíra     BA      NÃO
# 15                  Abaré     BA      NÃO
# 16                 Abatiá     PR      NÃO
# 17          Abdon Batista     SC      NÃO
# 18        Abel Figueiredo     PA      NÃO
# 19           Abelardo Luz     SC      NÃO
# 20             Abre Campo     MG      NÃO
# ...
