# %%
dados = [
    {"dia": 12, "mes": 2, "ano": 2019, "temp": 30.5},
    {"dia": 18, "mes": 3, "ano": 2019, "temp": 29.1},
    {"dia": 22, "mes": 4, "ano": 2019, "temp": 28.5},
    {"dia": 17, "mes": 5, "ano": 2019, "temp": 26.4}]

for dado in dados:
    data = f'{dado["dia"]:02d} / {dado["mes"]:02d} / {dado["ano"]}'
    temperatura = f'Temperatura: {dado["temp"]}°C'
    print(f'# {data}: {temperatura}')
# Out:
# # 12 / 02 / 2019: Temperatura: 30.5°C
# # 18 / 03 / 2019: Temperatura: 29.1°C
# # 22 / 04 / 2019: Temperatura: 28.5°C
# # 17 / 05 / 2019: Temperatura: 26.4°C
