# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dfdados1 = pd.read_csv('dados1.csv')
display(dfdados1)
# Out:
#          ID Region of residence  Age of Subject  Time spent on Online Class  \
# 0        R1           Delhi-NCR              21                         2.0
# 1        R2           Delhi-NCR              21                         0.0
# 2        R3           Delhi-NCR              20                         7.0
# 3        R4           Delhi-NCR              20                         3.0
# 4        R5           Delhi-NCR              21                         3.0
# ...     ...                 ...             ...                         ...
# 1177  R1191           Delhi-NCR              12                         3.0
# 1178  R1192           Delhi-NCR              14                         6.0
# 1179  R1193           Delhi-NCR              13                         4.0
# 1180  R1194           Delhi-NCR              14                         5.0
# 1181  R1195           Delhi-NCR              13                         5.0
#
# ...

# %% [markdown]
# Gráfico de Linhas

# %%
graf_linha = sns.lineplot(data = dfdados1, x="Time spent on self study", y="Age of Subject", color = "blue")
graf_linha.set_title("Tempo gasto de estudo pela idade")
plt.show(graf_linha)

# %% [markdown]
# Gráficos de Barras

# %%
filtered_data = data[['Number of meals per day', 'Region of residence']]
count_data = filtered_data.groupby(['Number of meals per day', 'Region of residence']).size().unstack()
plt.figure(figsize=(12, 6))
count_data.plot(kind='bar', stacked=True)

plt.title('Refeições por dia X Região de Residência')
plt.xlabel('Refeições por dia')
plt.ylabel('Região de Residência')
plt.legend(title='Residência')
plt.show()

# %% [markdown]
# Histograma

# %%
plt.hist(data=dfdados1, x='Time spent on sleep', color='blue')
plt.xlabel("Tempo de sono (horas)")
plt.title("Tempo gasto de sono")
plt.show()

# %% [markdown]
# Histograma com Estimativa de Densidade do Kernel

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Time spent on sleep'], kde=True, color='blue', label='Time spent on sleep', bins=15, stat='density')
sns.histplot(data['Time spent on social media'], kde=True, color='orange', label='Time spent on social media', bins=15, stat='density')

plt.title('Tempo de sono X Tempo em mídias sociais')
plt.xlabel('Horas')
plt.ylabel('Densidade')
plt.legend()

plt.show()

# %% [markdown]
# Boxplot

# %%
import seaborn as sns
filtered_data = data[['Medium for online class', 'Time spent on Online Class']]
plt.figure(figsize=(12, 6))
sns.boxplot(x='Medium for online class', y='Time spent on Online Class', data=filtered_data)

plt.title('Tempo Gasto em Aula Online por Dispositivos')
plt.xlabel('Dispositivos')
plt.ylabel('Tempo Gasto em Aula Online (horas)')

plt.show()

# %% [markdown]
# Gráfico de Densidade

# %%
sns.kdeplot(data=dfdados1, x='Health issue during lockdown')
plt.title('Problemas de Saúde na Pandemia Covid-19')
plt.xlabel('Problemas de saúde durante a Pandemia COVID19')
plt.ylabel('Densidade')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-b500a643e9c2> in <cell line: 1>()
# ----> 1 sns.kdeplot(data=dfdados1, x='Health issue during lockdown')
#       2 plt.title('Problemas de Saúde na Pandemia Covid-19')
#       3 plt.xlabel('Problemas de saúde durante a Pandemia COVID19')
#       4 plt.ylabel('Densidade')
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1677         ax = plt.gca()
#    1678
# -> 1679     p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1680
#    1681     method = ax.fill_between if fill else ax.plot
# ...
